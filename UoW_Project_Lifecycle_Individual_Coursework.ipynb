# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.45.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.13.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.36.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Illegal_Dumping_Incidents.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243 entries, 0 to 2242
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NIRS Data     2243 non-null   object
#  1   Unnamed: 1    2243 non-null   object
#  2   Unnamed: 2    2243 non-null   object
#  3   Unnamed: 3    2243 non-null   object
#  4   Unnamed: 4    2243 non-null   object
#  5   Unnamed: 5    2243 non-null   object
#  6   Unnamed: 6    2241 non-null   object
#  7   Officer Data  419 non-null    object
#  8   Unnamed: 8    358 non-null    object
#  9   Unnamed: 9    152 non-null    object
#  10  Unnamed: 10   322 non-null    object
#  11  Unnamed: 11   33 non-null     object
#  12  Unnamed: 12   45 non-null     object
#  13  Unnamed: 13   777 non-null    object
#  14  Unnamed: 14   1470 non-null   object
#  15  CMS Data      2243 non-null   object
#  16  Unnamed: 16   116 non-null    object
#  17  Unnamed: 17   13 non-null     object
#  18  Unnamed: 18   166 non-null    object
#  19  Unnamed: 19   166 non-null    object
#  20  Unnamed: 20   166 non-null    object
#  21  Unnamed: 21   160 non-null    object
#  22  Unnamed: 22   158 non-null    object
#  23  Unnamed: 23   1 non-null      object
#  24  Unnamed: 24   1 non-null      object
# dtypes: object(25)
# memory usage: 438.2+ KB

# %%
data.head(10)
# Out:
#          NIRS Data                         Unnamed: 1  \
# 0  Incident Number                               Area
# 1      23130061613                      West Midlands
# 2     533511180111                             Thames
# 3      18130108308  Lincolnshire and Northamptonshire
# 4      14130226004                      East Midlands
# 5     133491084890             Cumbria and Lancashire
# 6     333481179859     Hertfordshire and North London
# 7      33461279718                         North East
# 8      33451185687                        East Anglia
# 9     433461185183                        East Anglia
#
#                 Unnamed: 2               Unnamed: 3  \
# 0  Completed Incident Date                Land Type
# 1                 1/2/2015    Private - Residential
# 2                 1/6/2015             Agricultural
# 3                 1/8/2015       Watercourse / Bank
# 4                 1/8/2015       Watercourse / Bank
# 5                 1/8/2015    Private - Residential
# 6                 1/9/2015  Commercial / Industrial
# 7                1/12/2015       Watercourse / Bank
# 8                1/12/2015             Council Land
# 9                1/12/2015                  Highway
#
#                     Unnamed: 4                  Unnamed: 5  \
# 0                   Waste Type               Incident Size
# 1                        green              small van load
# 2               animal carcass            transit van load
# 3  chemical drums, oil or fuel       car boot load or less
# 4  chemical drums, oil or fuel           other single item
# 5       other house hold waste              small van load
# 6      black bags - commercial              small van load
# 7                  white goods           other single item
# 8       other commercial waste  significant/multiple loads
# 9       other commercial waste           tipper lorry load
#
#                      Unnamed: 6 Officer Data Unnamed: 8 Unnamed: 9  ...  \
# 0  Overall Environmental Impact       Larger  Organised  Hazardous  ...
# 1                             3          NaN        NaN        NaN  ...
# 2                             3          NaN        NaN        NaN  ...
# 3                             3          NaN        NaN        NaN  ...
# 4                             3          NaN        NaN        NaN  ...
# 5                             3          NaN        NaN        Yes  ...
# 6                             4          NaN        NaN        NaN  ...
# 7                             3          NaN        NaN        NaN  ...
# 8                             3          Yes        Yes        NaN  ...
# 9                             3          Yes        Yes        NaN  ...
#
#                      CMS Data Unnamed: 16              Unnamed: 17  \
# 0         Incident Start Date  Waste Type  Waste Marked Hazardous?
# 1  No Outcome Recorded in CMS         NaN                      NaN
# 2  No Outcome Recorded in CMS         NaN                      NaN
# 3                  12/15/2014         NaN                      NaN
# 4  No Outcome Recorded in CMS         NaN                      NaN
# 5  No Outcome Recorded in CMS         NaN                      NaN
# 6                  12/18/2014         NaN                      NaN
# 7  No Outcome Recorded in CMS         NaN                      NaN
# 8  No Outcome Recorded in CMS         NaN                      NaN
# 9  No Outcome Recorded in CMS         NaN                      NaN
#
#                             Unnamed: 18  \
# 0                            Act/Byelaw
# 1                                   NaN
# 2                                   NaN
# 3  Environmental Permitting Regulations
# 4                                   NaN
# 5                                   NaN
# 6          Environmental Protection Act
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
#
#                                          Unnamed: 19           Unnamed: 20  \
# 0                                      Laymans Terms        Section/Byelaw
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3  (Referring back to Regulation 12) Cause or kno...   Regulation 38(1)(a)
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
# 6  Depositing or knowingly causing or knowingly p...  EPA Section 33(1)(a)
# 7                                                NaN                   NaN
# 8                                                NaN                   NaN
# 9                                                NaN                   NaN
#
#           Unnamed: 21        Unnamed: 22    Unnamed: 23         Unnamed: 24
# 0  Final Action Taken  Final Action Date  Notice Served  Date Notice Served
# 1                 NaN                NaN            NaN                 NaN
# 2                 NaN                NaN            NaN                 NaN
# 3   No Further Action           1/8/2015            NaN                 NaN
# 4                 NaN                NaN            NaN                 NaN
# 5                 NaN                NaN            NaN                 NaN
# 6             Caution         12/18/2014            NaN                 NaN
# 7                 NaN                NaN            NaN                 NaN
# 8                 NaN                NaN            NaN                 NaN
# 9                 NaN                NaN            NaN                 NaN
#
# [10 rows x 25 columns]

# %%
data = data.iloc[:, :7]
data.columns = data.iloc[0]
data = data.iloc[1:].reset_index(drop=True)

data.head(10)
# Out:
# 0 Incident Number                               Area Completed Incident Date  \
# 0     23130061613                      West Midlands                1/2/2015
# 1    533511180111                             Thames                1/6/2015
# 2     18130108308  Lincolnshire and Northamptonshire                1/8/2015
# 3     14130226004                      East Midlands                1/8/2015
# 4    133491084890             Cumbria and Lancashire                1/8/2015
# 5    333481179859     Hertfordshire and North London                1/9/2015
# 6     33461279718                         North East               1/12/2015
# 7     33451185687                        East Anglia               1/12/2015
# 8    433461185183                        East Anglia               1/12/2015
# 9      3345882082                      West Midlands               1/14/2015
#
# 0                Land Type                          Waste Type  \
# 0    Private - Residential                               green
# 1             Agricultural                      animal carcass
# 2       Watercourse / Bank         chemical drums, oil or fuel
# 3       Watercourse / Bank         chemical drums, oil or fuel
# 4    Private - Residential              other house hold waste
# 5  Commercial / Industrial             black bags - commercial
# 6       Watercourse / Bank                         white goods
# 7             Council Land              other commercial waste
# 8                  Highway              other commercial waste
# 9  Commercial / Industrial  construction/demolition/excavation
#
# 0               Incident Size Overall Environmental Impact
# 0              small van load                            3
# 1            transit van load                            3
# 2       car boot load or less                            3
# 3           other single item                            3
# 4              small van load                            3
# 5              small van load                            4
# 6           other single item                            3
# 7  significant/multiple loads                            3
# 8           tipper lorry load                            3
# 9           tipper lorry load                            3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Incident Number               2242 non-null   object
#  1   Area                          2242 non-null   object
#  2   Completed Incident Date       2242 non-null   object
#  3   Land Type                     2242 non-null   object
#  4   Waste Type                    2242 non-null   object
#  5   Incident Size                 2242 non-null   object
#  6   Overall Environmental Impact  2240 non-null   object
# dtypes: object(7)
# memory usage: 122.7+ KB

# %%
data.isna().sum()/len(data)*100
# Out:
# 0
# Incident Number                 0.000000
# Area                            0.000000
# Completed Incident Date         0.000000
# Land Type                       0.000000
# Waste Type                      0.000000
# Incident Size                   0.000000
# Overall Environmental Impact    0.089206
# dtype: float64

# %%
data['Overall Environmental Impact'].fillna(data['Overall Environmental Impact'].mode()[0], inplace=True)
# Out:
# <ipython-input-12-72d261f68e89>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Overall Environmental Impact'].fillna(data['Overall Environmental Impact'].mode()[0], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Incident Number               2242 non-null   object
#  1   Area                          2242 non-null   object
#  2   Completed Incident Date       2242 non-null   object
#  3   Land Type                     2242 non-null   object
#  4   Waste Type                    2242 non-null   object
#  5   Incident Size                 2242 non-null   object
#  6   Overall Environmental Impact  2242 non-null   object
# dtypes: object(7)
# memory usage: 122.7+ KB

# %%
data.columns
# Out:
# Index(['Incident Number', 'Area', 'Completed Incident Date', 'Land Type',
#        'Waste Type', 'Incident Size', 'Overall Environmental Impact'],
#       dtype='object', name=0)

# %%
data.isna().sum()/len(data)*100
# Out:
# 0
# Incident Number                 0.0
# Area                            0.0
# Completed Incident Date         0.0
# Land Type                       0.0
# Waste Type                      0.0
# Incident Size                   0.0
# Overall Environmental Impact    0.0
# dtype: float64

# %%
cleaned_data = data.to_csv("/content/cleaned_Illegal_Dumping_Incidents.csv", index=False)

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

st.sidebar.title("Filters")
selected_area = st.sidebar.multiselect("Select Area(s):", options=data["Area"].unique())

data["Completed Incident Date"] = pd.to_datetime(data["Completed Incident Date"], errors='coerce')

min_date = data["Completed Incident Date"].min().date()
max_date = data["Completed Incident Date"].max().date()
date_range = st.sidebar.date_input("Date Range", [min_date, max_date])

data["Overall Environmental Impact"] = pd.to_numeric(data["Overall Environmental Impact"], errors='coerce')
min_impact = int(data["Overall Environmental Impact"].min())
max_impact = int(data["Overall Environmental Impact"].max())
impact_range = st.sidebar.slider(
    "Overall Environmental Impact Range",
    min_value=min_impact,
    max_value=max_impact,
    value=(min_impact, max_impact)
)

filtered_data = data.copy()
if selected_area:
    filtered_data = filtered_data[filtered_data["Area"].isin(selected_area)]

filtered_data = filtered_data[(filtered_data["Overall Environmental Impact"].between(*impact_range))]
filtered_data = filtered_data[
    (filtered_data["Completed Incident Date"] >= pd.to_datetime(date_range[0])) &
    (filtered_data["Completed Incident Date"] <= pd.to_datetime(date_range[1]))
]

st.title("Illegal Dumping Incidents Dashboard")
st.markdown("Explore incident trends, impact levels, and more.")
# Out:
# 2025-05-01 08:53:32.204 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.293
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-05-01 08:53:32.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.subheader("Top 10 Areas by Number of Incidents")
top_areas = filtered_data["Area"].value_counts().head(10)
fig1, ax1 = plt.subplots()
top_areas.plot(kind='bar', ax=ax1)
ax1.set_xlabel("Area")
ax1.set_ylabel("Number of Incidents")
ax1.set_title("Top 10 Areas")
st.pyplot(fig1)
# Out:
# 2025-05-01 08:53:32.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:32.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.subheader("Incidents Over Time")
monthly = filtered_data["Completed Incident Date"].dt.to_period("M").value_counts().sort_index()
fig2, ax2 = plt.subplots()
monthly.plot(marker='o', ax=ax2)
ax2.set_xlabel("Month")
ax2.set_ylabel("Number of Incidents")
ax2.set_title("Incidents Over Time")
st.pyplot(fig2)
# Out:
# 2025-05-01 08:53:33.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.subheader("Environmental Impact Distribution")
fig3, ax3 = plt.subplots()
filtered_data["Overall Environmental Impact"].astype(int).value_counts().sort_index().plot(kind='bar', ax=ax3)
ax3.set_xlabel("Impact Level")
ax3.set_ylabel("Number of Incidents")
ax3.set_title("Impact Ratings")
st.pyplot(fig3)
# Out:
# 2025-05-01 08:53:33.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.subheader("Most Common Incident Sizes")
fig4, ax4 = plt.subplots()
filtered_data["Incident Size"].value_counts().head(10).plot(kind='bar', ax=ax4)
ax4.set_xlabel("Incident Size")
ax4.set_ylabel("Number of Incidents")
ax4.set_title("Incident Size Distribution")
st.pyplot(fig4)

st.markdown("---")
st.markdown("Data Source: Illegal Dumping Incidents Dataset")
# Out:
# 2025-05-01 08:53:33.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:33.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:34.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:34.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:34.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:34.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:34.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-01 08:53:34.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
